# %%
# Load CSV using Pandas from URL 
from pandas import read_csv 
url = 'breast_cancer_data.csv' 
data = read_csv(url) 
print(data.shape)
# Out:
# (300, 11)

# %%
# View first 20 rows 
from pandas import read_csv 
filename = "breast_cancer_data.csv" 
data = read_csv(filename) 
peek = data.head(20)
print(peek)
# Out:
#     Unnamed: 0  Clump Thickness  Uniformity of Cell Size  \
# 0            0                5                        1
# 1            1                5                        4
# 2            2                3                        1
# 3            3                6                        8
# 4            4                4                        1
# 5            5                8                       10
# 6            6                1                        1
# 7            7                2                        1
# 8            8                2                        1
# 9            9                4                        2
# 10          10                1                        1
# 11          11                2                        1
# 12          12                5                        3
# 13          13                1                        1
# 14          14                8                        7
# ...

# %%
# Hypothesis testing using Pearson
from matplotlib import pyplot 
from pandas import read_csv 
import numpy 
from scipy import stats

filename = "breast_cancer_data.csv" 
data = read_csv(filename) 

# Compute p-value
pearson_coef, p_value = stats.pearsonr(data['Clump Thickness'], data['Target'])
print("The Pearson correlation coefficient is", pearson_coef, "with a p-value of", p_value)
# Out:
# The Pearson correlation coefficient is 0.734299460930431 with a p-value of 4.584880199549879e-52

# %%
# Hypothesis testing using Pearson
from matplotlib import pyplot 
from pandas import read_csv 
import numpy 
from scipy import stats

filename = "breast_cancer_data.csv" 
data = read_csv(filename) 

# Compute p-value
pearson_coef, p_value = stats.pearsonr(data['Mitoses'], data['Target'])
print("The Pearson correlation coefficient is", pearson_coef, "with a p-value of", p_value)
# Out:
# The Pearson correlation coefficient is 0.41697399963693516 with a p-value of 4.765981275969667e-14

# %%
# Compare Algorithms 
from pandas import read_csv 
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot 
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectKBest 
from sklearn.pipeline import FeatureUnion 
from sklearn.preprocessing import MinMaxScaler

# load dataset 
filename = "breast_cancer_data.csv" 
data = read_csv(filename) 
df=data.drop(columns=['Unnamed: 0'])
array = data.values
X = array[:,0:9] 
Y = array[:,9] 



# create feature union 
features = [] 
#scaler = MinMaxScaler(feature_range=(0, 1)) 
#rescaledX = scaler.fit_transform(X) 
#features.append(('standardize' , StandardScaler()))
features.append(('standardize' , MinMaxScaler()))
features.append(('pca' , PCA(n_components=3))) 
features.append(('select_best' , SelectKBest(k=6))) 
feature_union = FeatureUnion(features) 

# create pipelie# 
estimators = []
estimators.append(('feature_union' , feature_union))
estimators.append((' SVM' , SVC()))
model = Pipeline(estimators)

#stimators.append(('logistic' , LogisticRegression())) 
model = Pipeline(estimators)

# prepare models 
#models = [] 

##models.append((' LR' , LogisticRegression())) 
#models.append((' LDA' , LinearDiscriminantAnalysis())) 
#models.append((' KNN' , KNeighborsClassifier())) 
#models.append((' CART' , DecisionTreeClassifier())) 
#models.append((' NB' , GaussianNB())) 
#models.append((' SVM' , SVC()))

# evaluate each model in turn 
results = [] 
#names = [] 
#scoring = 'accuracy' 
#for name, model in models: 
kfold = KFold(n_splits=10, random_state=7) 
cv_results = cross_val_score(model, rescaledX, Y, cv=kfold, scoring=scoring) 
results.append(cv_results)
# names.append(name) 
msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
print(msg)
# boxplot algorithm comparison 
fig = pyplot.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
pyplot.boxplot(results) 
ax.set_xticklabels(names)
pyplot.show()
# Out:
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...

# %%
# Compare Algorithms 
from pandas import read_csv 
from matplotlib import pyplot 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC 

# load dataset 
filename = 'breast_cancer_data.csv' 
dataframe = read_csv(filename) 
df=data.drop(columns=['Unnamed: 0'])
array = data.values
array = dataframe.values 
X = array[:,0:9] 
Y = array[:,9] 

# prepare models 
models = [] 
models.append((' LR' , LogisticRegression())) 
models.append((' LDA' , LinearDiscriminantAnalysis())) 
models.append((' KNN' , KNeighborsClassifier())) 
models.append((' CART' , DecisionTreeClassifier())) 
models.append((' NB' , GaussianNB())) 
models.append((' SVM' , SVC()))

# evaluate each model in turn 
results = [] 
names = [] 
scoring = 'accuracy' 
for name, model in models: 
    kfold = KFold(n_splits=10, random_state=7) 
    cv_results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring) 
    results.append(cv_results)
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# boxplot algorithm comparison 
fig = pyplot.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
pyplot.boxplot(results) 
ax.set_xticklabels(names)
pyplot.show()
# Out:
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
# Scatterplot Matrix 
from matplotlib import pyplot 
from pandas import read_csv 
from pandas.plotting import scatter_matrix 
filename = 'breast_cancer_data.csv'
names =['Clump Thickness', 'Uniformity of Cell Size', 'Marginal Adhesion','Single Epithelial  Cell Size','Bare Nuclei','Bland Chromatin','Normal Nucleoli','Mitoses','Target']
data = read_csv(filename) 
scatter_matrix(data) 
pyplot.show()

# %%
# View first 20 rows 
from pandas import read_csv 
filename = 'breast_cancer_data.csv' 
data = read_csv(filename) 
names =['Clump Thickness', 'Uniformity of Cell Size', 'Marginal Adhesion','Single Epithelial  Cell Size','Bare Nuclei','Bland Chromatin','Normal Nucleoli','Mitoses','Target']
peek = data.head(20)
print(peek)
# Out:
#     Unnamed: 0  Clump Thickness  Uniformity of Cell Size  \
# 0            0                5                        1
# 1            1                5                        4
# 2            2                3                        1
# 3            3                6                        8
# 4            4                4                        1
# 5            5                8                       10
# 6            6                1                        1
# 7            7                2                        1
# 8            8                2                        1
# 9            9                4                        2
# 10          10                1                        1
# 11          11                2                        1
# 12          12                5                        3
# 13          13                1                        1
# 14          14                8                        7
# ...

# %%
# Correlation Matrix Plot 
from matplotlib import pyplot 
from pandas import read_csv 
import numpy 
filename = 'breast_cancer_data.csv'
df=data.drop(columns=['Unnamed: 0'])
names = data.values
names =['Clump', 'Uniformity', 'Marginal','Size','Nuclei','Bland','Nucleoli','Mitoses']
data = read_csv(filename) 
correlations = data.corr() 

# plot correlation matrix 
fig = pyplot.figure() 
ax = fig.add_subplot(111) 
cax = ax.matshow(correlations, vmin=-1, vmax=1) 
fig.colorbar(cax) 
ticks = numpy.arange(0,10,1) 
ax.set_xticks(ticks) 
ax.set_yticks(ticks) 
ax.set_xticklabels(names) 
ax.set_yticklabels(names) 
pyplot.show()

# %%
# Univariate Histograms 
from matplotlib import pyplot 
from pandas import read_csv 
filename = 'breast_cancer_data.csv'
df=data.drop(columns=['Unnamed: 0'])
names = df.values
names =['Clump', 'Uniformity', 'Marginal','Size','Nuclei','Bland','Nucleoli','Mitoses','Target']
data = read_csv(filename) 
data.hist() 
pyplot.tight_layout()
pyplot.show()

# %%
# Univariate Histograms 
from matplotlib import pyplot 
from pandas import read_csv 
filename = 'breast_cancer_data.csv'
names =['Clump', 'Uniformity', 'Marginal','Size','Nuclei','Bland','Nucleoli','Mitoses']
data = read_csv(filename) 
print("Cancer data set dimensions{}".format(dataset.shape))
data.head()
# Out:
# Cancer data set dimensions(300, 11)
#    Unnamed: 0  Clump Thickness  Uniformity of Cell Size  \
# 0           0                5                        1
# 1           1                5                        4
# 2           2                3                        1
# 3           3                6                        8
# 4           4                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion    \
# 0                         1                    1
# 1                         4                    5
# 2                         1                    1
# 3                         8                    1
# 4                         1                    3
#
#    Single Epithelial  Cell Size  Bare Nuclei  Bland Chromatin  \
# 0                             2            1                3
# 1                             7           10                3
# 2                             2            2                3
# ...

# %%
# Statistical Summary 
from pandas import read_csv 
from pandas import set_option 
filename = 'Breast_Cancer_data.csv' 
data = read_csv(filename) 
set_option('display.width', 100) 
set_option('precision', 3) 
description = data.describe() 
print(description)
# Out:
#        Unnamed: 0  Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# count     300.000          300.000                  300.000                   300.000
# mean      149.500            4.873                    3.547                     3.717
# std        86.747            3.116                    3.133                     3.088
# min         0.000            1.000                    1.000                     1.000
# 25%        74.750            2.000                    1.000                     1.000
# 50%       149.500            5.000                    2.000                     3.000
# 75%       224.250            8.000                    5.000                     6.000
# max       299.000           10.000                   10.000                    10.000
#
#        Marginal Adhesion    Single Epithelial  Cell Size  Bare Nuclei  Bland Chromatin  \
# count              300.000                       300.000      300.000          300.000
# ...

# %%
# Feature Extraction with Univariate Statistical Tests (Chi-squared for classification) 
from pandas import read_csv 
from numpy import set_printoptions 
from sklearn.feature_selection import SelectKBest 
from sklearn.feature_selection import chi2 

# load data 
filename = 'breast_cancer_data.csv'
#names =['Clump', 'size', 'shape','Marginal','epethelial','Nuclei','Bland','Nucleoli','Mitoses']
dataframe = read_csv(filename) 
data= dataframe.drop(columns=['Unnamed: 0'])
array = data.values 
X = array[:,0:9] 
Y = array[:,9] 

# feature extraction 
test = SelectKBest(score_func=chi2, k=4) 
fit = test.fit(X, Y) 

# summarize scores
set_printoptions(precision=3) 
print(fit.scores_) 
features = fit.transform(X) 

# summarize selected features 
print(features[0:5,:])
pandas.DataFrame(fit.scores_.reshape(1, 9).tolist(), columns=data.columns[:-1]).T.sort_values(0, ascending=False)
# Out:
# [321.215 485.755 483.712 344.435 218.069 633.264 148.342 423.171 116.31 ]
# [[ 1  1  1  1]
#  [ 4  4 10  2]
#  [ 1  1  2  1]
#  [ 8  8  4  7]
#  [ 1  1  1  1]]
#                                     0
# Bare Nuclei                   633.264
# Uniformity of Cell Size       485.755
# Uniformity of Cell Shape      483.712
# Normal Nucleoli               423.171
# Marginal Adhesion             344.435
# Clump Thickness               321.215
# Single Epithelial  Cell Size  218.069
# Bland Chromatin               148.342
# Mitoses                       116.310

# %%
# Feature Extraction with RFE 
from pandas import read_csv 
import matplotlib.pyplot as plt 
from sklearn.feature_selection import RFE 
from sklearn.linear_model import LogisticRegression 

# load data 
filename = 'breast_cancer_data.csv'
df=data.drop(columns=['Unnamed: 0'])
names = df.values
#names =['Clump', 'size', 'shape','Marginal','epethelial','Nuclei','Bland','Nucleoli','Mitoses']
dataframe = read_csv(filename) 
array = dataframe.values 
X = array[:,0:9] 
Y = array[:,9] 

# feature extraction 
model = LogisticRegression() 
rfe = RFE(model, 3) 
fit = rfe.fit(X, Y) 
print("Num Features: %d" % fit.n_features_) 
print("Selected Features: %s" % fit.support_) 
print("Feature Ranking: %s" % fit.ranking_)
#plt.plot(array) 
#pyplot.show()
pd.DataFrame(fit.ranking_.reshape(1, 9).tolist(), columns=dataframe.columns[:-1]).T.sort_values(0, ascending=True)
# Out:
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
# Compare Algorithms 
from pandas import read_csv 
from matplotlib import pyplot 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC 

# load dataset 
filename = 'breast_cancer_data.csv' 
dataframe = read_csv(filename) 
array = dataframe.values 
X = array[:,0:9] 
Y = array[:,9] 

# prepare models 
models = [] 
models.append((' LR' , LogisticRegression())) 
models.append((' LDA' , LinearDiscriminantAnalysis())) 
models.append((' KNN' , KNeighborsClassifier())) 
models.append((' CART' , DecisionTreeClassifier())) 
models.append((' NB' , GaussianNB())) 
models.append((' SVM' , SVC()))

# evaluate each model in turn 
results = [] 
names = [] 
scoring = 'accuracy' 
for name, model in models: 
    kfold = KFold(n_splits=10, random_state=7) 
    cv_results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring) 
    results.append(cv_results)
    names.append(name) 
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
    print(msg)
# boxplot algorithm comparison 
fig = pyplot.figure() 
fig.suptitle('Algorithm Comparison') 
ax = fig.add_subplot(111) 
pyplot.boxplot(results) 
ax.set_xticklabels(names)
pyplot.show()
# Out:
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\riszty\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...
